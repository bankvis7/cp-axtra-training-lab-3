# %% [markdown]
# <a href="https://colab.research.google.com/github/bankvis7/cp-axtra-training-lab-3/blob/main/lab3_gguf_llama_cpp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 3 รันโมเดล GGUF ด้วย llama.cpp
#
# เนื้อหา:
# - การโหลดโมเดล GGUF
# - รัน inference ด้วย llama-cpp บน CPU

# %% [markdown]
# * * *
# ## การติดตั้ง Python wrapper สำหรับ llama.cpp

# %%
# CPU llama-cpp-python
# !uv pip install llama-cpp-python

# %%
from huggingface_hub import hf_hub_download
from llama_cpp import Llama
from google.colab import userdata

# %% [markdown]
# ---
#
# # ขั้นตอนที่ 1: การโหลดโมเดล

# %%
model_name = "unsloth/gemma-2-it-GGUF"
model_file = "gemma-2-2b-it.q4_k_m.gguf"
HF_TOKEN = userdata.get('HF_TOKEN')
model_path = hf_hub_download(model_name,
                             filename=model_file,
                             local_dir='/content',
                             token=HF_TOKEN)
print("My model path: ", model_path)

# %% [markdown]
# ---
#
# # ขั้นตอนที่ 2: การทดสอบ Inference

# %%
from llama_cpp import Llama

llm = Llama(model_path=model_path,
            n_gpu_layers=-1)

# %%
response = llm("Where is Bangkok?", max_tokens=500)

# %%
print(response['choices'][0]['text'])

# %% [markdown]
# ----
